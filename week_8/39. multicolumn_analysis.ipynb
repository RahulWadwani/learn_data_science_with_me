# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('playstore.csv')

# %%
df.head()
# Out:
#                                                  app        category  rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana          FAMILY     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#      review  size  type    installs  price content_rating
# 0     159.0  19.0  Free     10000.0    0.0       Everyone
# 1     974.0  14.0  Free    500000.0    0.0       Everyone
# 2   87510.0   8.0  Free   5000000.0    0.0       Everyone
# 3  215644.0  25.0  Free  50000000.0    0.0           Teen
# 4     967.0   2.0  Free    100000.0    0.0       Everyone

# %%
df['app'] = df['app']

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9649 entries, 0 to 9648
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   app             9648 non-null   object
#  1   category        9648 non-null   object
#  2   rating          9648 non-null   float64
#  3   review          9649 non-null   float64
#  4   size            9648 non-null   float64
#  5   type            9648 non-null   object
#  6   installs        9648 non-null   float64
#  7   price           9648 non-null   float64
#  8   content_rating  9648 non-null   object
# dtypes: float64(5), object(4)
# memory usage: 678.6+ KB
# (9649, 9)

# %% [markdown]
# # converting dataframe to an array

# %%
# 
df['category'].nunique()
# Out:
# 33

# %%
data = df.values

# %%
data
# Out:
# array([['Photo Editor & Candy Camera & Grid & ScrapBook',
#         'ART_AND_DESIGN', 4.1, ..., 10000.0, 0.0, 'Everyone'],
#        ['Coloring book moana', 'FAMILY', 3.9, ..., 500000.0, 0.0,
#         'Everyone'],
#        ['U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#         'ART_AND_DESIGN', 4.7, ..., 5000000.0, 0.0, 'Everyone'],
#        ...,
#        ['The SCP Foundation DB fr nn5n', 'BOOKS_AND_REFERENCE', 4.5, ...,
#         1000.0, 0.0, 'Mature 17+'],
#        ['iHoroscope - 2018 Daily Horoscope & Astrology', 'LIFESTYLE',
#         4.5, ..., 10000000.0, 0.0, 'Everyone'],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
data.shape
# Out:
# (9649, 9)

# %%
data[0]
# Out:
# array(['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN',
#        4.1, 159.0, 19.0, 'Free', 10000.0, 0.0, 'Everyone'], dtype=object)

# %% [markdown]
# # 2) slicing the Array

# %%
data[0:5,0:3]
# Out:
# array([['Photo Editor & Candy Camera & Grid & ScrapBook',
#         'ART_AND_DESIGN', 4.1],
#        ['Coloring book moana', 'FAMILY', 3.9],
#        ['U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#         'ART_AND_DESIGN', 4.7],
#        ['Sketch - Draw & Paint', 'ART_AND_DESIGN', 4.5],
#        ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', 4.3]],
#       dtype=object)

# %%
df.head()
# Out:
#                                                  app        category  rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana          FAMILY     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#      review  size  type    installs  price content_rating
# 0     159.0  19.0  Free     10000.0    0.0       Everyone
# 1     974.0  14.0  Free    500000.0    0.0       Everyone
# 2   87510.0   8.0  Free   5000000.0    0.0       Everyone
# 3  215644.0  25.0  Free  50000000.0    0.0           Teen
# 4     967.0   2.0  Free    100000.0    0.0       Everyone

# %%
for i in data:
    print(i)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook' 'ART_AND_DESIGN' 4.1
#  159.0 19.0 'Free' 10000.0 0.0 'Everyone']
# ['Coloring book moana' 'FAMILY' 3.9 974.0 14.0 'Free' 500000.0 0.0
#  'Everyone']
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps' 'ART_AND_DESIGN' 4.7
#  87510.0 8.0 'Free' 5000000.0 0.0 'Everyone']
# ['Sketch - Draw & Paint' 'ART_AND_DESIGN' 4.5 215644.0 25.0 'Free'
#  50000000.0 0.0 'Teen']
# ['Pixel Draw - Number Art Coloring Book' 'ART_AND_DESIGN' 4.3 967.0 2.0
#  'Free' 100000.0 0.0 'Everyone']
# ['Paper flowers instructions' 'ART_AND_DESIGN' 4.4 167.0 5.0 'Free'
#  50000.0 0.0 'Everyone']
# ['Smoke Effect Photo Maker - Smoke Editor' 'ART_AND_DESIGN' 3.8 178.0 19.0
#  'Free' 50000.0 0.0 'Everyone']
# ['Infinite Painter' 'ART_AND_DESIGN' 4.1 36815.0 29.0 'Free' 1000000.0 0.0
#  'Everyone']
# ['Garden Coloring Book' 'ART_AND_DESIGN' 4.4 13791.0 33.0 'Free' 1000000.0
#  0.0 'Everyone']
# ['Kids Paint Free - Drawing Fun' 'ART_AND_DESIGN' 4.7 121.0 3.0 'Free'
# ...

# %% [markdown]
# # 3) Analyse - print all apps name which comes under art_and_design

# %%
df.head()
# Out:
#                                                  app        category  rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana          FAMILY     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#      review  size  type    installs  price content_rating
# 0     159.0  19.0  Free     10000.0    0.0       Everyone
# 1     974.0  14.0  Free    500000.0    0.0       Everyone
# 2   87510.0   8.0  Free   5000000.0    0.0       Everyone
# 3  215644.0  25.0  Free  50000000.0    0.0           Teen
# 4     967.0   2.0  Free    100000.0    0.0       Everyone

# %%
for i in data:
    if i[1] == 'ART_AND_DESIGN':
        print(i[0])
# Out:
# Photo Editor & Candy Camera & Grid & ScrapBook
# U Launcher Lite – FREE Live Cool Themes, Hide Apps
# Sketch - Draw & Paint
# Pixel Draw - Number Art Coloring Book
# Paper flowers instructions
# Smoke Effect Photo Maker - Smoke Editor
# Infinite Painter
# Garden Coloring Book
# Kids Paint Free - Drawing Fun
# Text on Photo - Fonteee
# Name Art Photo Editor - Focus n Filters
# Tattoo Name On My Photo Editor
# Mandala Coloring Book
# 3D Color Pixel by Number - Sandbox Art Coloring
# Photo Designer - Write your name with shapes
# 350 Diy Room Decor Ideas
# FlipaClip - Cartoon animation
# ibis Paint X
# Logo Maker - Small Business
# Boys Photo Editor - Six Pack & Men's Suit
# Superheroes Wallpapers | 4K Backgrounds
# HD Mickey Minnie Wallpapers
# Harley Quinn wallpapers HD
# Colorfit - Drawing & Coloring
# Animated Photo Editor
# Pencil Sketch Drawing
# Easy Realistic Drawing Tutorial
# Pink Silver Bow Keyboard Theme
# Art Drawing Ideas
# Anime Manga Coloring Book
# Easy Origami Ideas
# ...

# %% [markdown]
# # 4) Analyse all the details of the application that comes under dating category

# %%
df['category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'FAMILY', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMMUNICATION', 'COMICS',
#        'DATING', 'TOOLS', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS',
#        'FINANCE', 'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'MEDICAL',
#        'HOUSE_AND_HOME', 'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME',
#        'SPORTS', 'VIDEO_PLAYERS', 'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY',
#        'TRAVEL_AND_LOCAL', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING',
#        'WEATHER', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION', nan],
#       dtype=object)

# %%
for i in data:
    if i[1] == 'AUTO_AND_VEHICLES':
        print('Name           : ',i[0])
        print('Rating         : ',i[2])
        print('Reviews        : ',i[3])
        print('Size           : ',i[4])
        print('Installs       : ',i[5])
        print('Type           : ',i[6])
        print('Price          : ',i[7])
        print('Content Rating : ',i[8])
        print('-'*50)
# Out:
# Name           :  Monster Truck Stunt 3D 2019
# Rating         :  4.2
# Reviews        :  367.0
# Size           :  25.0
# Installs       :  Free
# Type           :  100000.0
# Price          :  0.0
# Content Rating :  Everyone
# --------------------------------------------------
# Name           :  Real Tractor Farming
# Rating         :  4.0
# Reviews        :  1598.0
# Size           :  56.0
# Installs       :  Free
# Type           :  1000000.0
# Price          :  0.0
# Content Rating :  Everyone
# --------------------------------------------------
# Name           :  Ultimate F1 Racing Championship
# Rating         :  3.8
# Reviews        :  284.0
# Size           :  57.0
# Installs       :  Free
# Type           :  100000.0
# Price          :  0.0
# Content Rating :  Everyone
# --------------------------------------------------
# Name           :  Used Cars and Trucks for Sale
# Rating         :  4.6
# Reviews        :  17057.0
# Size           :  10.0
# Installs       :  Free
# ...

# %% [markdown]
# # 5) Search application based on their name

# %%
title = 'chat'
n = 1
for i in data:
    if (title.lower() in i[0].lower()):
        print(str(n),'-',i)
        n += 1
# Out:
# 1 - ['HipChat - Chat Built for Teams' 'BUSINESS' 3.8 5868.0 20.0 'Free'
#  500000.0 0.0 'Everyone']
# 2 - ['Messenger – Text and Video Chat for Free' 'COMMUNICATION' 4.0 56642847.0
#  10.0 'Free' 1000000000.0 0.0 'Everyone']
# 3 - ['imo free video calls and chat' 'COMMUNICATION' 4.3 4785892.0 11.0 'Free'
#  500000000.0 0.0 'Everyone']
# 4 - ['Skype Lite - Free Video Call & Chat' 'COMMUNICATION' 4.2 33053.0 22.0
#  'Free' 5000000.0 0.0 'Everyone']
# 5 - ['WeChat' 'COMMUNICATION' 4.2 5387631.0 10.0 'Free' 100000000.0 0.0
#  'Everyone']
# 6 - ['Omlet Chat' 'COMMUNICATION' 3.9 40751.0 35.0 'Free' 10000000.0 0.0
#  'Teen']
# 7 - ['free video calls and chat' 'COMMUNICATION' 4.2 594720.0 10.0 'Free'
#  50000000.0 0.0 'Everyone']
# 8 - ['Glide - Video Chat Messenger' 'COMMUNICATION' 4.3 350154.0 10.0 'Free'
#  10000000.0 0.0 'Everyone']
# 9 - ['JusTalk - Free Video Calls and Fun Video Chat' 'COMMUNICATION' 4.6
#  191032.0 26.0 'Free' 5000000.0 0.0 'Everyone']
# ...

# %%
for i in data:
    print(type(i[0]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %% [markdown]
# # print app details with rating 5

# %%
df.head()
# Out:
#                                                  app        category  rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana          FAMILY     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#      review  size  type    installs  price content_rating
# 0     159.0  19.0  Free     10000.0    0.0       Everyone
# 1     974.0  14.0  Free    500000.0    0.0       Everyone
# 2   87510.0   8.0  Free   5000000.0    0.0       Everyone
# 3  215644.0  25.0  Free  50000000.0    0.0           Teen
# 4     967.0   2.0  Free    100000.0    0.0       Everyone

# %%
c = 1
for i in data:
    if (i[2] == 5):
        print(str(c),'-',i[0])
        c += 1
# Out:
# 1 - Hojiboy Tojiboyev Life Hacks
# 2 - American Girls Mobile Numbers
# 3 - Awake Dating
# 4 - Spine- The dating app
# 5 - Girls Live Talk - Free Text and Video Chat
# 6 - Online Girls Chat Group
# 7 - Speeding Joyride & Car Meet App
# 8 - SUMMER SONIC app
# 9 - Prosperity
# 10 - Mindvalley U Tallinn 2018
# 11 - Eternal life
# 12 - Super Hearing Secret Voices Recorder PRO
# 13 - FHR 5-Tier 2.0
# 14 - Sway Medical
# 15 - Labs on Demand
# 16 - Dermatology Atlas (Colored & Illustrative)
# 17 - Tablet Reminder
# 18 - Galaxies of Hope
# 19 - KBA-EZ Health Guide
# 20 - FoothillsVet
# 21 - PrimeDelivery
# 22 - You're an Anime
# 23 - Anatomy & Physiology Vocabulary Exam Review App
# 24 - NCLEX Multi-topic Nursing Exam Review-Quiz & notes
# 25 - Basics of Orthopaedics
# 26 - Clinic Doctor EHr
# 27 - 420 BZ Budeze Delivery
# 28 - BP Journal - Blood Pressure Diary
# 29 - Zen Leaf
# 30 - ADS-B Driver
# 31 - P-Home for KLWP
# 32 - Android P Style Icon Pack
# 33 - R Programing Offline Tutorial
# ...

# %%
for i in data:
    if (i[2] == 5):
        print('Name           : ',i[0])
        print('Rating         : ',i[2])
        print('Reviews        : ',i[3])
        print('Size           : ',i[4])
        print('Installs       : ',i[5])
        print('Type           : ',i[6])
        print('Price          : ',i[7])
        print('Content Rating : ',i[8])
        print('-'*50)
# Out:
# Name           :  Hojiboy Tojiboyev Life Hacks
# Rating         :  5.0
# Reviews        :  15.0
# Size           :  37.0
# Installs       :  Free
# Type           :  1000.0
# Price          :  0.0
# Content Rating :  Everyone
# --------------------------------------------------
# Name           :  American Girls Mobile Numbers
# Rating         :  5.0
# Reviews        :  5.0
# Size           :  4.0
# Installs       :  Free
# Type           :  1000.0
# Price          :  0.0
# Content Rating :  Mature 17+
# --------------------------------------------------
# Name           :  Awake Dating
# Rating         :  5.0
# Reviews        :  2.0
# Size           :  70.0
# Installs       :  Free
# Type           :  100.0
# Price          :  0.0
# Content Rating :  Mature 17+
# --------------------------------------------------
# Name           :  Spine- The dating app
# Rating         :  5.0
# Reviews        :  5.0
# Size           :  9.0
# Installs       :  Free
# Type           :  500.0
# ...

# %% [markdown]
# # 7) list all the paid apps in ART_AND_DESIGN

# %%
print('-'*50)
for i in data:
    if (str(i[5]).lower() =='paid') and (i[1].lower() == 'art_and_design'):
        print('Name           : ',i[0])
        print('Rating         : ',i[2])
        print('Reviews        : ',i[3])
        print('Size           : ',i[4])
        print('Installs       : ',i[5])
        print('Type           : ',i[6])
        print('Price          : ',i[7])
        print('Content Rating : ',i[8])
        print('-'*50)
        break
# Out:
# --------------------------------------------------
# Name           :  X Launcher Pro: PhoneX Theme, OS11 Control Center
# Rating         :  4.7
# Reviews        :  801.0
# Size           :  3.0
# Installs       :  Paid
# Type           :  5000.0
# Price          :  149.0
# Content Rating :  Everyone
# --------------------------------------------------

# %% [markdown]
# # 8) list all the paid games with rating more than 4.5

# %%
for i in data:
    if i[2] >= 4.5 and i[1] == 'GAME' and ((i[5]).lower() == 'paid'.lower()):
        print('Name           : ',i[0])
        print('Price          : ',i[7])
        print('-'*50)
# Out:
# Name           :  Clue
# Price          :  149.0
# --------------------------------------------------
# Name           :  The Room: Old Sins
# Price          :  374.0
# --------------------------------------------------
# Name           :  Farming Simulator 18
# Price          :  374.0
# --------------------------------------------------
# Name           :  RollerCoaster Tycoon® Classic
# Price          :  449.0
# --------------------------------------------------
# Name           :  Star Wars ™: DIRTY
# Price          :  749.0
# --------------------------------------------------
# Name           :  Monument Valley 2
# Price          :  374.0
# --------------------------------------------------
# Name           :  Hitman Sniper
# Price          :  74.0
# --------------------------------------------------
# Name           :  The World Ends With You
# Price          :  1349.0
# --------------------------------------------------
# Name           :  Traps n' Gemstones
# ...

# %% [markdown]
# # 9) list all paid Games with rating more than 4.5

# %%
for i in data:
    if i[2] == 5 and i[1] == 'GAME' and ((i[5]).lower() == 'paid'.lower()):
        print('Name           : ',i[0])
        print('Rating         : ',i[2])
        print('Reviews        : ',i[3])
        print('Size           : ',i[4])
        print('Installs       : ',i[5])
        print('Type           : ',i[6])
        print('Price          : ',i[7])
        print('Content Rating : ',i[8])
        print('-'*50)
# Out:
# Name           :  Ra Ga Ba
# Rating         :  5.0
# Reviews        :  2.0
# Size           :  20.0
# Installs       :  Paid
# Type           :  1.0
# Price          :  111.0
# Content Rating :  Everyone
# --------------------------------------------------
# Name           :  211:CK
# Rating         :  5.0
# Reviews        :  8.0
# Size           :  38.0
# Installs       :  Paid
# Type           :  10.0
# Price          :  74.0
# Content Rating :  Teen
# --------------------------------------------------
# Name           :  Santa's Monster Shootout DX
# Rating         :  5.0
# Reviews        :  4.0
# Size           :  33.0
# Installs       :  Paid
# Type           :  50.0
# Price          :  149.0
# Content Rating :  Teen
# --------------------------------------------------
# Name           :  Mu.F.O.
# Rating         :  5.0
# Reviews        :  2.0
# Size           :  16.0
# Installs       :  Paid
# Type           :  1.0
# Price          :  74.0
# Content Rating :  Everyone
# ...

# %% [markdown]
# # 10) list all free apps with 10000 + reviews, 100000+ installs for everyone

# %%
df.head()
# Out:
#                                                  app        category  rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana          FAMILY     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#      review  size  type    installs  price content_rating
# 0     159.0  19.0  Free     10000.0    0.0       Everyone
# 1     974.0  14.0  Free    500000.0    0.0       Everyone
# 2   87510.0   8.0  Free   5000000.0    0.0       Everyone
# 3  215644.0  25.0  Free  50000000.0    0.0           Teen
# 4     967.0   2.0  Free    100000.0    0.0       Everyone

# %%
for i in data:
    if i[5] == 'Paid' and i[3] >= 10000 and i[6]>=100000 and i[8] == 'Everyone' :
        print('Name           : ',i[0])
        print('Rating         : ',i[2])
        print('Reviews        : ',i[3])
        print('Size           : ',i[4])
        print('Installs       : ',i[5])
        print('Type           : ',i[6])
        print('Price          : ',i[7])
        print('Content Rating : ',i[8])
        print('-'*50)
# Out:
# Name           :  TurboScan: scan documents and receipts in PDF
# Rating         :  4.7
# Reviews        :  11442.0
# Size           :  6.0
# Installs       :  Paid
# Type           :  100000.0
# Price          :  374.0
# Content Rating :  Everyone
# --------------------------------------------------
# Name           :  Tiny Scanner Pro: PDF Doc Scan
# Rating         :  4.8
# Reviews        :  10295.0
# Size           :  39.0
# Installs       :  Paid
# Type           :  100000.0
# Price          :  374.0
# Content Rating :  Everyone
# --------------------------------------------------
# Name           :  Puffin Browser Pro
# Rating         :  4.0
# Reviews        :  18247.0
# Size           :  10.0
# Installs       :  Paid
# Type           :  100000.0
# Price          :  299.0
# Content Rating :  Everyone
# --------------------------------------------------
# Name           :  Toca Life: City
# Rating         :  4.7
# Reviews        :  31100.0
# Size           :  24.0
# ...

# %% [markdown]
# # 11) print application details of photo editor and candy camera and grid and scrapbook

# %%
for i in data:
    if i[0] == 'Photo Editor & Candy Camera & Grid & ScrapBook':
        print('Name           : ',i[0])
        print('Rating         : ',i[2])
        print('Reviews        : ',i[3])
        print('Size           : ',i[4])
        print('Installs       : ',i[5])
        print('Type           : ',i[6])
        print('Price          : ',i[7])
        print('Content Rating : ',i[8])
        print('-'*50)
# Out:
# Name           :  Photo Editor & Candy Camera & Grid & ScrapBook
# Rating         :  4.1
# Reviews        :  159.0
# Size           :  19.0
# Installs       :  Free
# Type           :  10000.0
# Price          :  0.0
# Content Rating :  Everyone
# --------------------------------------------------
